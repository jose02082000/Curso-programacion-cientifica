# %% [markdown]
# <a href="https://colab.research.google.com/github/jose02082000/Curso-programacion-cientifica/blob/main/ejercicios/ejercicio_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hola, GitHub!")
# Out:
# Hola, GitHub!
